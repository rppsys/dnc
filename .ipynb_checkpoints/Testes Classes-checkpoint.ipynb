# %%
# %matplotlib notebook
import stepPlot as sp
Condutor = sp.ClasseAgente('Condutor',True,5,5,4,0)
Condutor.plotaAgente(20)
# Out:
# <img src="data:image/png;base64,..." width="895.5833333333334">

# %%
# Comentei para deixar de exemplo
# sp.doStep(Condutor.pD,'ABR',Condutor.pE,Condutor.pD)
# Out:
# pD.ABR

# %%
# sp.doStep(Condutor.pE,'JUN',Condutor.pE,Condutor.pD)
# Condutor.plotaAgente(20)
# Out:
# pE.JUN
# <img src="data:image/png;base64,..." width="895.5833333333334">

# %%
Condutor.agenteDoStep('pD','ABR')
Condutor.plotaAgente(20)
# Out:
# Condutor - pD.ABR
# <img src="data:image/png;base64,..." width="895.5833333333334">

# %%
Condutor.retPeDireitoPoint()
# Out:
# (8.0, 5)
