# %%
import criarDBTemp as ct
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-9730da928171> in <module>
# ----> 1 import criarDBTemp as ct
#
# ~/prog/dnc/lab/criarDBTemp.py in <module>
#       4 import datetime
#       5 import numpy as np
# ----> 6 import pandas as pd
#       7 import csv
#       8 import os
#
# ModuleNotFoundError: No module named 'pandas'

# %%
ct.gerarDB('Bachata')
# Out:
# #####-#####-#####-#####-#####
# Ritmo: Bachata
# Arquivo: DB\Bachata\dbDanceBachata.db
# #####-#####-#####-#####-#####
#
# #----------=----------#
# tbNO:
#     typeNO  codPointer  drwGX  drwGY  drwLev  drwHei  drwPos drwRel  booActive
# cod
# 1     root           0     -1     -1      -1      -1      -1                 1
# 2      stp           1     -1     -1      -1      -1      -1                 1
# 3      stp           2     -1     -1      -1      -1      -1                 1
# 4      stp           3     -1     -1      -1      -1      -1                 1
# 5      stp           4     -1     -1      -1      -1      -1                 1
# 6      stp           5     -1     -1      -1      -1      -1                 1
# 7      stp           6     -1     -1      -1      -1      -1                 1
# 8      stp           7     -1     -1      -1      -1      -1                 1
# 9      stp           8     -1     -1      -1      -1      -1                 1
# 10     stp           9     -1     -1      -1      -1      -1                 1
# 11     stp          10     -1     -1      -1      -1      -1                 1
# 12     stp          11     -1     -1      -1      -1      -1                 1
# 13     stp          12     -1     -1      -1      -1      -1                 1
# 14     stp          13     -1     -1      -1      -1      -1                 1
# 15     stp          14     -1     -1      -1      -1      -1                 1
# 16     stp          15     -1     -1      -1      -1      -1                 1
# 17     stp          16     -1     -1      -1      -1      -1                 1
# 18     stp          17     -1     -1      -1      -1      -1                 1
# 19     stp          18     -1     -1      -1      -1      -1                 1
# 20     stp          19     -1     -1      -1      -1      -1                 1
# 21     stp          20     -1     -1      -1      -1      -1                 1
# 22     stp          21     -1     -1      -1      -1      -1                 1
# 23     stp          22     -1     -1      -1      -1      -1                 1
# 24     stp          23     -1     -1      -1      -1      -1                 1
# 25     stp          24     -1     -1      -1      -1      -1                 1
# 26     stp          25     -1     -1      -1      -1      -1                 1
# 27     stp          26     -1     -1      -1      -1      -1                 1
# 28     stp          27     -1     -1      -1      -1      -1                 1
# 29     stp          28     -1     -1      -1      -1      -1                 1
# 30     stp          29     -1     -1      -1      -1      -1                 1
# 31     stp          30     -1     -1      -1      -1      -1                 1
# 32     stp          31     -1     -1      -1      -1      -1                 1
# 33     stp          32     -1     -1      -1      -1      -1                 1
# 34     stp          33     -1     -1      -1      -1      -1                 1
# 35     stp          34     -1     -1      -1      -1      -1                 1
# 36     stp          35     -1     -1      -1      -1      -1                 1
# 37     stp          36     -1     -1      -1      -1      -1                 1
# #----------=----------#
# tbAD:
#     typeAD  codFrom  codTo
# cod
# 1    1.org        1      2
# 2    1.org        2      3
# 3    1.org        3      4
# 4    1.org        4      5
# 5    1.org        5      6
# 6    1.org        6      7
# 7    1.org        7      8
# 8    1.org        7      9
# 9    1.org        7     10
# 10   1.org        6     11
# 11   1.org       11     12
# 12   1.org       11     13
# 13   1.org       11     14
# 14   1.org        5     15
# 15   1.org       15     16
# 16   1.org       15     17
# 17   1.org        5     18
# 18   1.org       18     19
# 19   1.org       18     20
# 20   1.org        3     21
# 21   1.org       21     22
# 22   1.org       22     23
# 23   1.org       23     24
# 24   1.org       24     25
# 25   1.org       24     26
# 26   1.org       24     27
# 27   1.org       23     28
# 28   1.org       28     29
# 29   1.org       28     30
# 30   1.org       28     31
# 31   1.org       22     32
# 32   1.org       32     33
# 33   1.org       32     34
# 34   1.org       22     35
# 35   1.org       35     36
# 36   1.org       35     37
# #----------=----------#
# tbSTP:
#        strNAME strTYPE strVALUE  codNO
# cod
# 0          STP    root               1
# 1      Bachata     mod               2
# 2           V1     sub               3
# 3     Condutor    cond               4
# 4          BAS     tag               5
# 5          LAT     tag               6
# 6          ESQ     tag               7
# 7          CAL    leaf               8
# 8          CHA    leaf               9
# 9          BAS    leaf              10
# 10         DIR     tag              11
# 11         CAL    leaf              12
# 12         CHA    leaf              13
# 13         BAS    leaf              14
# 14         VER     tag              15
# 15         FRT    leaf              16
# 16         TRS    leaf              17
# 17         LUG     tag              18
# 18         ESQ    leaf              19
# 19         DIR    leaf              20
# 20   Conduzido    cond              21
# 21         BAS     tag              22
# 22         LAT     tag              23
# 23         ESQ     tag              24
# 24         CAL    leaf              25
# 25         CHA    leaf              26
# 26         BAS    leaf              27
# 27         DIR     tag              28
# 28         CAL    leaf              29
# 29         CHA    leaf              30
# 30         BAS    leaf              31
# 31         VER     tag              32
# 32         FRT    leaf              33
# 33         TRS    leaf              34
# 34         LUG     tag              35
# 35         ESQ    leaf              36
# 36         DIR    leaf              37
# #----------=----------#
# view DePara:
#     typeAD  codFrom from_strNAME from_strTYPE from_strVALUE  codTo to_strNAME  \
# cod
# 1    1.org        1          STP         root                    2    Bachata
# 2    1.org        2      Bachata          mod                    3         V1
# 3    1.org        3           V1          sub                    4   Condutor
# 4    1.org        4     Condutor         cond                    5        BAS
# 5    1.org        5          BAS          tag                    6        LAT
# 6    1.org        6          LAT          tag                    7        ESQ
# 7    1.org        7          ESQ          tag                    8        CAL
# 8    1.org        7          ESQ          tag                    9        CHA
# 9    1.org        7          ESQ          tag                   10        BAS
# 10   1.org        6          LAT          tag                   11        DIR
# 11   1.org       11          DIR          tag                   12        CAL
# 12   1.org       11          DIR          tag                   13        CHA
# 13   1.org       11          DIR          tag                   14        BAS
# 14   1.org        5          BAS          tag                   15        VER
# 15   1.org       15          VER          tag                   16        FRT
# 16   1.org       15          VER          tag                   17        TRS
# 17   1.org        5          BAS          tag                   18        LUG
# 18   1.org       18          LUG          tag                   19        ESQ
# 19   1.org       18          LUG          tag                   20        DIR
# 20   1.org        3           V1          sub                   21  Conduzido
# 21   1.org       21    Conduzido         cond                   22        BAS
# 22   1.org       22          BAS          tag                   23        LAT
# 23   1.org       23          LAT          tag                   24        ESQ
# 24   1.org       24          ESQ          tag                   25        CAL
# 25   1.org       24          ESQ          tag                   26        CHA
# 26   1.org       24          ESQ          tag                   27        BAS
# 27   1.org       23          LAT          tag                   28        DIR
# 28   1.org       28          DIR          tag                   29        CAL
# 29   1.org       28          DIR          tag                   30        CHA
# 30   1.org       28          DIR          tag                   31        BAS
# 31   1.org       22          BAS          tag                   32        VER
# 32   1.org       32          VER          tag                   33        FRT
# 33   1.org       32          VER          tag                   34        TRS
# 34   1.org       22          BAS          tag                   35        LUG
# 35   1.org       35          LUG          tag                   36        ESQ
# 36   1.org       35          LUG          tag                   37        DIR
#
#     to_strTYPE to_strVALUE
# cod
# 1          mod
# 2          sub
# 3         cond
# 4          tag
# 5          tag
# 6          tag
# 7         leaf
# 8         leaf
# 9         leaf
# 10         tag
# 11        leaf
# 12        leaf
# 13        leaf
# 14         tag
# 15        leaf
# 16        leaf
# 17         tag
# 18        leaf
# 19        leaf
# 20        cond
# 21         tag
# 22         tag
# 23         tag
# 24        leaf
# 25        leaf
# 26        leaf
# 27         tag
# 28        leaf
# 29        leaf
# 30        leaf
# 31         tag
# 32        leaf
# 33        leaf
# 34         tag
# 35        leaf
# 36        leaf
# #####-#####-#####-#####-#####
# #####-#####-#####-#####-#####

# %%
df = ct.retPandasDfFromSQL('''
SELECT
tbSTP.cod as cod,
tbSTP.strNAME as strNAME,
tbSTP.strTYPE as strTYPE,
tbSTP.strVALUE as strVALUE,
tbSTP.codNO as codNO
FROM
tbSTP
WHERE
tbSTP.strTYPE = 'leaf'    
''')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-00cf07b74dcd> in <module>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
ct.conectarDB('Bachata')
# Out:
# #####-#####-#####-#####-#####
# Ritmo: Bachata
# Arquivo: DB\Bachata\dbDanceBachata.db
# #####-#####-#####-#####-#####
#
# #----------=----------#
# tbNO:
#     typeNO  codPointer  drwGX  drwGY  drwLev  drwHei  drwPos drwRel  booActive
# cod
# 1     root           0     -1     -1      -1      -1      -1                 1
# 2      stp           1     -1     -1      -1      -1      -1                 1
# 3      stp           2     -1     -1      -1      -1      -1                 1
# 4      stp           3     -1     -1      -1      -1      -1                 1
# 5      stp           4     -1     -1      -1      -1      -1                 1
# 6      stp           5     -1     -1      -1      -1      -1                 1
# 7      stp           6     -1     -1      -1      -1      -1                 1
# 8      stp           7     -1     -1      -1      -1      -1                 1
# 9      stp           8     -1     -1      -1      -1      -1                 1
# 10     stp           9     -1     -1      -1      -1      -1                 1
# 11     stp          10     -1     -1      -1      -1      -1                 1
# 12     stp          11     -1     -1      -1      -1      -1                 1
# 13     stp          12     -1     -1      -1      -1      -1                 1
# 14     stp          13     -1     -1      -1      -1      -1                 1
# 15     stp          14     -1     -1      -1      -1      -1                 1
# 16     stp          15     -1     -1      -1      -1      -1                 1
# 17     stp          16     -1     -1      -1      -1      -1                 1
# 18     stp          17     -1     -1      -1      -1      -1                 1
# 19     stp          18     -1     -1      -1      -1      -1                 1
# 20     stp          19     -1     -1      -1      -1      -1                 1
# 21     stp          20     -1     -1      -1      -1      -1                 1
# 22     stp          21     -1     -1      -1      -1      -1                 1
# 23     stp          22     -1     -1      -1      -1      -1                 1
# 24     stp          23     -1     -1      -1      -1      -1                 1
# 25     stp          24     -1     -1      -1      -1      -1                 1
# 26     stp          25     -1     -1      -1      -1      -1                 1
# 27     stp          26     -1     -1      -1      -1      -1                 1
# 28     stp          27     -1     -1      -1      -1      -1                 1
# 29     stp          28     -1     -1      -1      -1      -1                 1
# 30     stp          29     -1     -1      -1      -1      -1                 1
# 31     stp          30     -1     -1      -1      -1      -1                 1
# 32     stp          31     -1     -1      -1      -1      -1                 1
# 33     stp          32     -1     -1      -1      -1      -1                 1
# 34     stp          33     -1     -1      -1      -1      -1                 1
# 35     stp          34     -1     -1      -1      -1      -1                 1
# 36     stp          35     -1     -1      -1      -1      -1                 1
# 37     stp          36     -1     -1      -1      -1      -1                 1
# #----------=----------#
# tbAD:
#     typeAD  codFrom  codTo
# cod
# 1    1.org        1      2
# 2    1.org        2      3
# 3    1.org        3      4
# 4    1.org        4      5
# 5    1.org        5      6
# 6    1.org        6      7
# 7    1.org        7      8
# 8    1.org        7      9
# 9    1.org        7     10
# 10   1.org        6     11
# 11   1.org       11     12
# 12   1.org       11     13
# 13   1.org       11     14
# 14   1.org        5     15
# 15   1.org       15     16
# 16   1.org       15     17
# 17   1.org        5     18
# 18   1.org       18     19
# 19   1.org       18     20
# 20   1.org        3     21
# 21   1.org       21     22
# 22   1.org       22     23
# 23   1.org       23     24
# 24   1.org       24     25
# 25   1.org       24     26
# 26   1.org       24     27
# 27   1.org       23     28
# 28   1.org       28     29
# 29   1.org       28     30
# 30   1.org       28     31
# 31   1.org       22     32
# 32   1.org       32     33
# 33   1.org       32     34
# 34   1.org       22     35
# 35   1.org       35     36
# 36   1.org       35     37
# #----------=----------#
# tbSTP:
#        strNAME strTYPE strVALUE  codNO
# cod
# 0          STP    root               1
# 1      Bachata     mod               2
# 2           V1     sub               3
# 3     Condutor    cond               4
# 4          BAS     tag               5
# 5          LAT     tag               6
# 6          ESQ     tag               7
# 7          CAL    leaf               8
# 8          CHA    leaf               9
# 9          BAS    leaf              10
# 10         DIR     tag              11
# 11         CAL    leaf              12
# 12         CHA    leaf              13
# 13         BAS    leaf              14
# 14         VER     tag              15
# 15         FRT    leaf              16
# 16         TRS    leaf              17
# 17         LUG     tag              18
# 18         ESQ    leaf              19
# 19         DIR    leaf              20
# 20   Conduzido    cond              21
# 21         BAS     tag              22
# 22         LAT     tag              23
# 23         ESQ     tag              24
# 24         CAL    leaf              25
# 25         CHA    leaf              26
# 26         BAS    leaf              27
# 27         DIR     tag              28
# 28         CAL    leaf              29
# 29         CHA    leaf              30
# 30         BAS    leaf              31
# 31         VER     tag              32
# 32         FRT    leaf              33
# 33         TRS    leaf              34
# 34         LUG     tag              35
# 35         ESQ    leaf              36
# 36         DIR    leaf              37
# #----------=----------#
# view DePara:
#     typeAD  codFrom from_strNAME from_strTYPE from_strVALUE  codTo to_strNAME  \
# cod
# 1    1.org        1          STP         root                    2    Bachata
# 2    1.org        2      Bachata          mod                    3         V1
# 3    1.org        3           V1          sub                    4   Condutor
# 4    1.org        4     Condutor         cond                    5        BAS
# 5    1.org        5          BAS          tag                    6        LAT
# 6    1.org        6          LAT          tag                    7        ESQ
# 7    1.org        7          ESQ          tag                    8        CAL
# 8    1.org        7          ESQ          tag                    9        CHA
# 9    1.org        7          ESQ          tag                   10        BAS
# 10   1.org        6          LAT          tag                   11        DIR
# 11   1.org       11          DIR          tag                   12        CAL
# 12   1.org       11          DIR          tag                   13        CHA
# 13   1.org       11          DIR          tag                   14        BAS
# 14   1.org        5          BAS          tag                   15        VER
# 15   1.org       15          VER          tag                   16        FRT
# 16   1.org       15          VER          tag                   17        TRS
# 17   1.org        5          BAS          tag                   18        LUG
# 18   1.org       18          LUG          tag                   19        ESQ
# 19   1.org       18          LUG          tag                   20        DIR
# 20   1.org        3           V1          sub                   21  Conduzido
# 21   1.org       21    Conduzido         cond                   22        BAS
# 22   1.org       22          BAS          tag                   23        LAT
# 23   1.org       23          LAT          tag                   24        ESQ
# 24   1.org       24          ESQ          tag                   25        CAL
# 25   1.org       24          ESQ          tag                   26        CHA
# 26   1.org       24          ESQ          tag                   27        BAS
# 27   1.org       23          LAT          tag                   28        DIR
# 28   1.org       28          DIR          tag                   29        CAL
# 29   1.org       28          DIR          tag                   30        CHA
# 30   1.org       28          DIR          tag                   31        BAS
# 31   1.org       22          BAS          tag                   32        VER
# 32   1.org       32          VER          tag                   33        FRT
# 33   1.org       32          VER          tag                   34        TRS
# 34   1.org       22          BAS          tag                   35        LUG
# 35   1.org       35          LUG          tag                   36        ESQ
# 36   1.org       35          LUG          tag                   37        DIR
#
#     to_strTYPE to_strVALUE
# cod
# 1          mod
# 2          sub
# 3         cond
# 4          tag
# 5          tag
# 6          tag
# 7         leaf
# 8         leaf
# 9         leaf
# 10         tag
# 11        leaf
# 12        leaf
# 13        leaf
# 14         tag
# 15        leaf
# 16        leaf
# 17         tag
# 18        leaf
# 19        leaf
# 20        cond
# 21         tag
# 22         tag
# 23         tag
# 24        leaf
# 25        leaf
# 26        leaf
# 27         tag
# 28        leaf
# 29        leaf
# 30        leaf
# 31         tag
# 32        leaf
# 33        leaf
# 34         tag
# 35        leaf
# 36        leaf
# #####-#####-#####-#####-#####
# #####-#####-#####-#####-#####

# %% [markdown]
# ##### ct.verificar()

# %%
ct.mostrar()
# Out:
# #####-#####-#####-#####-#####
# Ritmo: ZOUK
# Arquivo: DB\ZOUK\dbDanceZOUK.db
# #####-#####-#####-#####-#####
#
# #----------=----------#
# tbNO:
#     typeNO  codPointer  drwGX  drwGY  drwLev  drwHei  drwPos drwRel  booActive
# cod
# 1     root           0     -1     -1      -1      -1      -1                 1
# 2      stp           1     -1     -1      -1      -1      -1                 1
# 3      stp           2     -1     -1      -1      -1      -1                 1
# 4      stp           3     -1     -1      -1      -1      -1                 1
# 5      stp           4     -1     -1      -1      -1      -1                 1
# 6      stp           5     -1     -1      -1      -1      -1                 1
# 7      stp           6     -1     -1      -1      -1      -1                 1
# 8      stp           7     -1     -1      -1      -1      -1                 1
# 9      stp           8     -1     -1      -1      -1      -1                 1
# 10     stp           9     -1     -1      -1      -1      -1                 1
# 11     stp          10     -1     -1      -1      -1      -1                 1
# 12     stp          11     -1     -1      -1      -1      -1                 1
# 13     stp          12     -1     -1      -1      -1      -1                 1
# 14     stp          13     -1     -1      -1      -1      -1                 1
# 15     stp          14     -1     -1      -1      -1      -1                 1
# 16     stp          15     -1     -1      -1      -1      -1                 1
# 17     stp          16     -1     -1      -1      -1      -1                 1
# 18     stp          17     -1     -1      -1      -1      -1                 1
# 19     stp          18     -1     -1      -1      -1      -1                 1
# 20     stp          19     -1     -1      -1      -1      -1                 1
# 21     stp          20     -1     -1      -1      -1      -1                 1
# 22     stp          21     -1     -1      -1      -1      -1                 1
# 23     stp          22     -1     -1      -1      -1      -1                 1
# 24     stp          23     -1     -1      -1      -1      -1                 1
# 25     stp          24     -1     -1      -1      -1      -1                 1
# 26     stp          25     -1     -1      -1      -1      -1                 1
# 27     stp          26     -1     -1      -1      -1      -1                 1
# 28     stp          27     -1     -1      -1      -1      -1                 1
# 29     stp          28     -1     -1      -1      -1      -1                 1
# 30     stp          29     -1     -1      -1      -1      -1                 1
# ..     ...         ...    ...    ...     ...     ...     ...    ...        ...
# 153    stp         152     -1     -1      -1      -1      -1                 1
# 154    stp         153     -1     -1      -1      -1      -1                 1
# 155    stp         154     -1     -1      -1      -1      -1                 1
# 156    stp         155     -1     -1      -1      -1      -1                 1
# 157    stp         156     -1     -1      -1      -1      -1                 1
# 158    stp         157     -1     -1      -1      -1      -1                 1
# 159    stp         158     -1     -1      -1      -1      -1                 1
# 160    stp         159     -1     -1      -1      -1      -1                 1
# 161    stp         160     -1     -1      -1      -1      -1                 1
# 162    stp         161     -1     -1      -1      -1      -1                 1
# 163    stp         162     -1     -1      -1      -1      -1                 1
# 164    stp         163     -1     -1      -1      -1      -1                 1
# 165    stp         164     -1     -1      -1      -1      -1                 1
# 166    stp         165     -1     -1      -1      -1      -1                 1
# 167    stp         166     -1     -1      -1      -1      -1                 1
# 168    stp         167     -1     -1      -1      -1      -1                 1
# 169    stp         168     -1     -1      -1      -1      -1                 1
# 170    stp         169     -1     -1      -1      -1      -1                 1
# 171    stp         170     -1     -1      -1      -1      -1                 1
# 172    stp         171     -1     -1      -1      -1      -1                 1
# 173    stp         172     -1     -1      -1      -1      -1                 1
# 174    stp         173     -1     -1      -1      -1      -1                 1
# 175    stp         174     -1     -1      -1      -1      -1                 1
# 176    stp         175     -1     -1      -1      -1      -1                 1
# 177    stp         176     -1     -1      -1      -1      -1                 1
# 178    stp         177     -1     -1      -1      -1      -1                 1
# 179    stp         178     -1     -1      -1      -1      -1                 1
# 180    stp         179     -1     -1      -1      -1      -1                 1
# 181    stp         180     -1     -1      -1      -1      -1                 1
# 182    stp         181     -1     -1      -1      -1      -1                 1
#
# [182 rows x 9 columns]
# #----------=----------#
# tbAD:
#      typeAD  codFrom  codTo
# cod
# 1     1.org        1      2
# 2     1.org        2      3
# 3     1.org        3      4
# 4     1.org        4      5
# 5     1.org        5      6
# 6     1.org        6      7
# 7     1.org        6      8
# 8     1.org        6      9
# 9     1.org        5     10
# 10    1.org       10     11
# 11    1.org       10     12
# 12    1.org        5     13
# 13    1.org       13     14
# 14    1.org       13     15
# 15    1.org        5     16
# 16    1.org       16     17
# 17    1.org       16     18
# 18    1.org       16     19
# 19    1.org        4     20
# 20    1.org       20     21
# 21    1.org       21     22
# 22    1.org       21     23
# 23    1.org        3     24
# 24    1.org       24     25
# 25    1.org       25     26
# 26    1.org       26     27
# 27    1.org       26     28
# 28    1.org       25     29
# 29    1.org       29     30
# 30    1.org       29     31
# ..      ...      ...    ...
# 152  1.prop       27    153
# 153  1.prop       27    154
# 154  1.prop       28    155
# 155  1.prop       28    156
# 156  1.prop       28    157
# 157  1.prop       28    158
# 158  1.prop       30    159
# 159  1.prop       30    160
# 160  1.prop       30    161
# 161  1.prop       30    162
# 162  1.prop       31    163
# 163  1.prop       31    164
# 164  1.prop       31    165
# 165  1.prop       31    166
# 166  1.prop       33    167
# 167  1.prop       33    168
# 168  1.prop       33    169
# 169  1.prop       33    170
# 170  1.prop       34    171
# 171  1.prop       34    172
# 172  1.prop       34    173
# 173  1.prop       34    174
# 174  1.prop       37    175
# 175  1.prop       37    176
# 176  1.prop       37    177
# 177  1.prop       37    178
# 178  1.prop       38    179
# 179  1.prop       38    180
# 180  1.prop       38    181
# 181  1.prop       38    182
#
# [181 rows x 3 columns]
# #----------=----------#
# tbSTP:
#           strNAME strTYPE                           strVALUE  codNO
# cod
# 0             STP    root                                         1
# 1            Zouk     mod                                         2
# 2              V1     sub                                         3
# 3        Condutor    cond                                         4
# 4             BAS     tag                                         5
# 5             LAT     tag                                         6
# 6             ESQ    leaf                                         7
# 7             DIR    leaf                                         8
# 8            ROTf    leaf                                         9
# 9             VER     tag                                        10
# 10            FRT    leaf                                        11
# 11            TRS    leaf                                        12
# 12            LUG     tag                                        13
# 13            ESQ    leaf                                        14
# 14            DIR    leaf                                        15
# 15            TRN     tag                                        16
# 16        LATpVER    leaf                                        17
# 17    VERpLAT-LUG    leaf                                        18
# 18   VERpLAT-ROTf    leaf                                        19
# 19            GIR     tag                                        20
# 20            LAT     tag                                        21
# 21            ESQ    leaf                                        22
# 22            DIR    leaf                                        23
# 23      Conduzido    cond                                        24
# 24            BAS     tag                                        25
# 25            LAT     tag                                        26
# 26            ESQ    leaf                                        27
# 27            DIR    leaf                                        28
# 28            VER     tag                                        29
# 29            FRT    leaf                                        30
# ..            ...     ...                                ...    ...
# 152         FIRST    prop                             pD.ACF    153
# 153          LAST    prop                             pD.JUN    154
# 154          NAME    prop  DNC_Zouk_V1_Conduzido_BAS_LAT_DIR    155
# 155         TOTAL    prop                                  6    156
# 156         FIRST    prop                             pE.ACF    157
# 157          LAST    prop                             pE.JUN    158
# 158          NAME    prop  DNC_Zouk_V1_Conduzido_BAS_VER_FRT    159
# 159         TOTAL    prop                                  6    160
# 160         FIRST    prop                             pD.FRT    161
# 161          LAST    prop                             pD.JUN    162
# 162          NAME    prop  DNC_Zouk_V1_Conduzido_BAS_VER_TRZ    163
# 163         TOTAL    prop                                  6    164
# 164         FIRST    prop                             pE.TRS    165
# 165          LAST    prop                             pE.JUN    166
# 166          NAME    prop  DNC_Zouk_V1_Conduzido_BAS_LUG_ESQ    167
# 167         TOTAL    prop                                  6    168
# 168         FIRST    prop                             pE.JUN    169
# 169          LAST    prop                             pE.JUN    170
# 170          NAME    prop  DNC_Zouk_V1_Conduzido_BAS_LUG_DIR    171
# 171         TOTAL    prop                                  6    172
# 172         FIRST    prop                             pD.JUN    173
# 173          LAST    prop                             pD.JUN    174
# 174          NAME    prop  STP_Zouk_V1_Conduzido_GIR_LAT_ESQ    175
# 175         TOTAL    prop                                  6    176
# 176         FIRST    prop                     pE.ABR(rot=fq)    177
# 177          LAST    prop                     pE.FRT(rot=fv)    178
# 178          NAME    prop  STP_Zouk_V1_Conduzido_GIR_LAT_DIR    179
# 179         TOTAL    prop                                  6    180
# 180         FIRST    prop                     pD.ABR(rot=fq)    181
# 181          LAST    prop                     pD.FRT(rot=fv)    182
#
# [182 rows x 4 columns]
# #----------=----------#
# view DePara:
#      typeAD  codFrom from_strNAME from_strTYPE from_strVALUE  codTo  \
# cod
# 1     1.org        1          STP         root                    2
# 2     1.org        2         Zouk          mod                    3
# 3     1.org        3           V1          sub                    4
# 4     1.org        4     Condutor         cond                    5
# 5     1.org        5          BAS          tag                    6
# 6     1.org        6          LAT          tag                    7
# 7     1.org        6          LAT          tag                    8
# 8     1.org        6          LAT          tag                    9
# 9     1.org        5          BAS          tag                   10
# 10    1.org       10          VER          tag                   11
# 11    1.org       10          VER          tag                   12
# 12    1.org        5          BAS          tag                   13
# 13    1.org       13          LUG          tag                   14
# 14    1.org       13          LUG          tag                   15
# 15    1.org        5          BAS          tag                   16
# 16    1.org       16          TRN          tag                   17
# 17    1.org       16          TRN          tag                   18
# 18    1.org       16          TRN          tag                   19
# 19    1.org        4     Condutor         cond                   20
# 20    1.org       20          GIR          tag                   21
# 21    1.org       21          LAT          tag                   22
# 22    1.org       21          LAT          tag                   23
# 23    1.org        3           V1          sub                   24
# 24    1.org       24    Conduzido         cond                   25
# 25    1.org       25          BAS          tag                   26
# 26    1.org       26          LAT          tag                   27
# 27    1.org       26          LAT          tag                   28
# 28    1.org       25          BAS          tag                   29
# 29    1.org       29          VER          tag                   30
# 30    1.org       29          VER          tag                   31
# ..      ...      ...          ...          ...           ...    ...
# 152  1.prop       27          ESQ         leaf                  153
# 153  1.prop       27          ESQ         leaf                  154
# 154  1.prop       28          DIR         leaf                  155
# 155  1.prop       28          DIR         leaf                  156
# 156  1.prop       28          DIR         leaf                  157
# 157  1.prop       28          DIR         leaf                  158
# 158  1.prop       30          FRT         leaf                  159
# 159  1.prop       30          FRT         leaf                  160
# 160  1.prop       30          FRT         leaf                  161
# 161  1.prop       30          FRT         leaf                  162
# 162  1.prop       31          TRS         leaf                  163
# 163  1.prop       31          TRS         leaf                  164
# 164  1.prop       31          TRS         leaf                  165
# 165  1.prop       31          TRS         leaf                  166
# 166  1.prop       33          ESQ         leaf                  167
# 167  1.prop       33          ESQ         leaf                  168
# 168  1.prop       33          ESQ         leaf                  169
# 169  1.prop       33          ESQ         leaf                  170
# 170  1.prop       34          DIR         leaf                  171
# 171  1.prop       34          DIR         leaf                  172
# 172  1.prop       34          DIR         leaf                  173
# 173  1.prop       34          DIR         leaf                  174
# 174  1.prop       37          ESQ         leaf                  175
# 175  1.prop       37          ESQ         leaf                  176
# 176  1.prop       37          ESQ         leaf                  177
# 177  1.prop       37          ESQ         leaf                  178
# 178  1.prop       38          DIR         leaf                  179
# 179  1.prop       38          DIR         leaf                  180
# 180  1.prop       38          DIR         leaf                  181
# 181  1.prop       38          DIR         leaf                  182
#
#        to_strNAME to_strTYPE                        to_strVALUE
# cod
# 1            Zouk        mod
# 2              V1        sub
# 3        Condutor       cond
# 4             BAS        tag
# 5             LAT        tag
# 6             ESQ       leaf
# 7             DIR       leaf
# 8            ROTf       leaf
# 9             VER        tag
# 10            FRT       leaf
# 11            TRS       leaf
# 12            LUG        tag
# 13            ESQ       leaf
# 14            DIR       leaf
# 15            TRN        tag
# 16        LATpVER       leaf
# 17    VERpLAT-LUG       leaf
# 18   VERpLAT-ROTf       leaf
# 19            GIR        tag
# 20            LAT        tag
# 21            ESQ       leaf
# 22            DIR       leaf
# 23      Conduzido       cond
# 24            BAS        tag
# 25            LAT        tag
# 26            ESQ       leaf
# 27            DIR       leaf
# 28            VER        tag
# 29            FRT       leaf
# 30            TRS       leaf
# ..            ...        ...                                ...
# 152         FIRST       prop                             pD.ACF
# 153          LAST       prop                             pD.JUN
# 154          NAME       prop  DNC_Zouk_V1_Conduzido_BAS_LAT_DIR
# 155         TOTAL       prop                                  6
# 156         FIRST       prop                             pE.ACF
# 157          LAST       prop                             pE.JUN
# 158          NAME       prop  DNC_Zouk_V1_Conduzido_BAS_VER_FRT
# 159         TOTAL       prop                                  6
# 160         FIRST       prop                             pD.FRT
# 161          LAST       prop                             pD.JUN
# 162          NAME       prop  DNC_Zouk_V1_Conduzido_BAS_VER_TRZ
# 163         TOTAL       prop                                  6
# 164         FIRST       prop                             pE.TRS
# 165          LAST       prop                             pE.JUN
# 166          NAME       prop  DNC_Zouk_V1_Conduzido_BAS_LUG_ESQ
# 167         TOTAL       prop                                  6
# 168         FIRST       prop                             pE.JUN
# 169          LAST       prop                             pE.JUN
# 170          NAME       prop  DNC_Zouk_V1_Conduzido_BAS_LUG_DIR
# 171         TOTAL       prop                                  6
# 172         FIRST       prop                             pD.JUN
# 173          LAST       prop                             pD.JUN
# 174          NAME       prop  STP_Zouk_V1_Conduzido_GIR_LAT_ESQ
# 175         TOTAL       prop                                  6
# 176         FIRST       prop                     pE.ABR(rot=fq)
# 177          LAST       prop                     pE.FRT(rot=fv)
# 178          NAME       prop  STP_Zouk_V1_Conduzido_GIR_LAT_DIR
# 179         TOTAL       prop                                  6
# 180         FIRST       prop                     pD.ABR(rot=fq)
# 181          LAST       prop                     pD.FRT(rot=fv)
#
# [181 rows x 9 columns]
# #####-#####-#####-#####-#####
# #####-#####-#####-#####-#####

# %%
ct.verificar()
# Out:
# #########
# codNo 8:STP_Bachata_V1_Condutor_BAS_LAT_ESQ_CAL existe! Coletando atributos
# ##########
#
#
# Nome: STP_Bachata_V1_Condutor_BAS_LAT_ESQ_CAL
#  Total: 15
#  First:pE.ABR
#  Last:pD.JUN*
#
# #########
# codNo 9:STP_Bachata_V1_Condutor_BAS_LAT_ESQ_CHA existe! Coletando atributos
# ##########
#
#
# Nome: STP_Bachata_V1_Condutor_BAS_LAT_ESQ_CHA
#  Total: 15
#  First:pE.ABR
#  Last:pE.LUG
#
# #########
# codNo 10:STP_Bachata_V1_Condutor_BAS_LAT_ESQ_BAS existe! Coletando atributos
# ##########
#
#
# Nome: STP_Bachata_V1_Condutor_BAS_LAT_ESQ_BAS
#  Total: 10
#  First:pE.ABR
#  Last:pD.JUN*
#
# #########
# codNo 12:STP_Bachata_V1_Condutor_BAS_LAT_DIR_CAL existe! Coletando atributos
# ##########
#
#
# Nome: STP_Bachata_V1_Condutor_BAS_LAT_DIR_CAL
#  Total: 15
#  First:pD.ABR
#  Last:pE.JUN*
#
# #########
# codNo 13:STP_Bachata_V1_Condutor_BAS_LAT_DIR_CHA existe! Coletando atributos
# ##########
#
#
# Nome: STP_Bachata_V1_Condutor_BAS_LAT_DIR_CHA
#  Total: 15
#  First:pD.ABR
#  Last:pD.LUG
#
# #########
# codNo 14:STP_Bachata_V1_Condutor_BAS_LAT_DIR_BAS existe! Coletando atributos
# ##########
#
#
# Nome: STP_Bachata_V1_Condutor_BAS_LAT_DIR_BAS
#  Total: 10
#  First:pD.ABR
#  Last:pE.JUN*
#
# #########
# codNo 16:STP_Bachata_V1_Condutor_BAS_VER_FRT existe! Coletando atributos
# ##########
#
#
# Nome: STP_Bachata_V1_Condutor_BAS_VER_FRT
#  Total: 10
#  First:pE.FRT
#  Last:pD.JUN*
#
# #########
# codNo 17:STP_Bachata_V1_Condutor_BAS_VER_TRS existe! Coletando atributos
# ##########
#
#
# Nome: STP_Bachata_V1_Condutor_BAS_VER_TRS
#  Total: 10
#  First:pD.TRS
#  Last:pE.JUN*
#
# #########
# codNo 19:STP_Bachata_V1_Condutor_BAS_LUG_ESQ existe! Coletando atributos
# ##########
#
#
# Nome: STP_Bachata_V1_Condutor_BAS_LUG_ESQ
#  Total: 10
#  First:pE.LUG
#  Last:pD.LUG*
#
# #########
# codNo 20:STP_Bachata_V1_Condutor_BAS_LUG_DIR existe! Coletando atributos
# ##########
#
#
# Nome: STP_Bachata_V1_Condutor_BAS_LUG_DIR
#  Total: 10
#  First:pD.LUG
#  Last:pE.LUG*
#
# #########
# codNo 25:STP_Bachata_V1_Conduzido_BAS_LAT_ESQ_CAL existe! Coletando atributos
# ##########
#
#
# Nome: STP_Bachata_V1_Condutor_BAS_LAT_ESQ_CAL
#  Total: 15
#  First:pE.ABR
#  Last:pD.JUN*
#
# #########
# codNo 26:STP_Bachata_V1_Conduzido_BAS_LAT_ESQ_CHA existe! Coletando atributos
# ##########
#
#
# Nome: STP_Bachata_V1_Condutor_BAS_LAT_ESQ_CHA
#  Total: 15
#  First:pE.ABR
#  Last:pE.LUG
#
# #########
# codNo 27:STP_Bachata_V1_Conduzido_BAS_LAT_ESQ_BAS existe! Coletando atributos
# ##########
#
#
# Nome: STP_Bachata_V1_Condutor_BAS_LAT_ESQ_BAS
#  Total: 10
#  First:pE.ABR
#  Last:pD.JUN*
#
# #########
# codNo 29:STP_Bachata_V1_Conduzido_BAS_LAT_DIR_CAL existe! Coletando atributos
# ##########
#
#
# Nome: STP_Bachata_V1_Condutor_BAS_LAT_DIR_CAL
#  Total: 15
#  First:pD.ABR
#  Last:pE.JUN*
#
# #########
# codNo 30:STP_Bachata_V1_Conduzido_BAS_LAT_DIR_CHA existe! Coletando atributos
# ##########
#
#
# Nome: STP_Bachata_V1_Condutor_BAS_LAT_DIR_CHA
#  Total: 15
#  First:pD.ABR
#  Last:pD.LUG
#
# #########
# codNo 31:STP_Bachata_V1_Conduzido_BAS_LAT_DIR_BAS existe! Coletando atributos
# ##########
#
#
# Nome: STP_Bachata_V1_Condutor_BAS_LAT_DIR_BAS
#  Total: 10
#  First:pD.ABR
#  Last:pE.JUN*
#
# #########
# codNo 33:STP_Bachata_V1_Conduzido_BAS_VER_FRT existe! Coletando atributos
# ##########
#
#
# Nome: STP_Bachata_V1_Condutor_BAS_VER_FRT
#  Total: 10
#  First:pE.FRT
#  Last:pD.JUN*
#
# #########
# codNo 34:STP_Bachata_V1_Conduzido_BAS_VER_TRS existe! Coletando atributos
# ##########
#
#
# Nome: STP_Bachata_V1_Condutor_BAS_VER_TRS
#  Total: 10
#  First:pD.TRS
#  Last:pE.JUN*
#
# #########
# codNo 36:STP_Bachata_V1_Conduzido_BAS_LUG_ESQ existe! Coletando atributos
# ##########
#
#
# Nome: STP_Bachata_V1_Condutor_BAS_LUG_ESQ
#  Total: 10
#  First:pE.LUG
#  Last:pD.LUG*
#
# #########
# codNo 37:STP_Bachata_V1_Conduzido_BAS_LUG_DIR existe! Coletando atributos
# ##########
#
#
# Nome: STP_Bachata_V1_Condutor_BAS_LUG_DIR
#  Total: 10
#  First:pD.LUG
#  Last:pE.LUG*
#     strNAME strTYPE strVALUE  codNO
# cod
# 7       CAL    leaf               8
# 8       CHA    leaf               9
# 9       BAS    leaf              10
# 11      CAL    leaf              12
# 12      CHA    leaf              13
# 13      BAS    leaf              14
# 15      FRT    leaf              16
# 16      TRS    leaf              17
# 18      ESQ    leaf              19
# 19      DIR    leaf              20
# 24      CAL    leaf              25
# 25      CHA    leaf              26
# 26      BAS    leaf              27
# 28      CAL    leaf              29
# 29      CHA    leaf              30
# 30      BAS    leaf              31
# 32      FRT    leaf              33
# 33      TRS    leaf              34
# 35      ESQ    leaf              36
# 36      DIR    leaf              37

# %%
ct.mostrar()
# Out:
# #####-#####-#####-#####-#####
# Ritmo: Bachata
# Arquivo: DB\Bachata\dbDanceBachata.db
# #####-#####-#####-#####-#####
#
# #----------=----------#
# tbNO:
#     typeNO  codPointer  drwGX  drwGY  drwLev  drwHei  drwPos drwRel  booActive
# cod
# 1     root           0     -1     -1      -1      -1      -1                 1
# 2      stp           1     -1     -1      -1      -1      -1                 1
# 3      stp           2     -1     -1      -1      -1      -1                 1
# 4      stp           3     -1     -1      -1      -1      -1                 1
# 5      stp           4     -1     -1      -1      -1      -1                 1
# 6      stp           5     -1     -1      -1      -1      -1                 1
# 7      stp           6     -1     -1      -1      -1      -1                 1
# 8      stp           7     -1     -1      -1      -1      -1                 1
# 9      stp           8     -1     -1      -1      -1      -1                 1
# 10     stp           9     -1     -1      -1      -1      -1                 1
# 11     stp          10     -1     -1      -1      -1      -1                 1
# 12     stp          11     -1     -1      -1      -1      -1                 1
# 13     stp          12     -1     -1      -1      -1      -1                 1
# 14     stp          13     -1     -1      -1      -1      -1                 1
# 15     stp          14     -1     -1      -1      -1      -1                 1
# 16     stp          15     -1     -1      -1      -1      -1                 1
# 17     stp          16     -1     -1      -1      -1      -1                 1
# 18     stp          17     -1     -1      -1      -1      -1                 1
# 19     stp          18     -1     -1      -1      -1      -1                 1
# 20     stp          19     -1     -1      -1      -1      -1                 1
# 21     stp          20     -1     -1      -1      -1      -1                 1
# 22     stp          21     -1     -1      -1      -1      -1                 1
# 23     stp          22     -1     -1      -1      -1      -1                 1
# 24     stp          23     -1     -1      -1      -1      -1                 1
# 25     stp          24     -1     -1      -1      -1      -1                 1
# 26     stp          25     -1     -1      -1      -1      -1                 1
# 27     stp          26     -1     -1      -1      -1      -1                 1
# 28     stp          27     -1     -1      -1      -1      -1                 1
# 29     stp          28     -1     -1      -1      -1      -1                 1
# 30     stp          29     -1     -1      -1      -1      -1                 1
# ..     ...         ...    ...    ...     ...     ...     ...    ...        ...
# 88     stp          87     -1     -1      -1      -1      -1                 1
# 89     stp          88     -1     -1      -1      -1      -1                 1
# 90     stp          89     -1     -1      -1      -1      -1                 1
# 91     stp          90     -1     -1      -1      -1      -1                 1
# 92     stp          91     -1     -1      -1      -1      -1                 1
# 93     stp          92     -1     -1      -1      -1      -1                 1
# 94     stp          93     -1     -1      -1      -1      -1                 1
# 95     stp          94     -1     -1      -1      -1      -1                 1
# 96     stp          95     -1     -1      -1      -1      -1                 1
# 97     stp          96     -1     -1      -1      -1      -1                 1
# 98     stp          97     -1     -1      -1      -1      -1                 1
# 99     stp          98     -1     -1      -1      -1      -1                 1
# 100    stp          99     -1     -1      -1      -1      -1                 1
# 101    stp         100     -1     -1      -1      -1      -1                 1
# 102    stp         101     -1     -1      -1      -1      -1                 1
# 103    stp         102     -1     -1      -1      -1      -1                 1
# 104    stp         103     -1     -1      -1      -1      -1                 1
# 105    stp         104     -1     -1      -1      -1      -1                 1
# 106    stp         105     -1     -1      -1      -1      -1                 1
# 107    stp         106     -1     -1      -1      -1      -1                 1
# 108    stp         107     -1     -1      -1      -1      -1                 1
# 109    stp         108     -1     -1      -1      -1      -1                 1
# 110    stp         109     -1     -1      -1      -1      -1                 1
# 111    stp         110     -1     -1      -1      -1      -1                 1
# 112    stp         111     -1     -1      -1      -1      -1                 1
# 113    stp         112     -1     -1      -1      -1      -1                 1
# 114    stp         113     -1     -1      -1      -1      -1                 1
# 115    stp         114     -1     -1      -1      -1      -1                 1
# 116    stp         115     -1     -1      -1      -1      -1                 1
# 117    stp         116     -1     -1      -1      -1      -1                 1
#
# [117 rows x 9 columns]
# #----------=----------#
# tbAD:
#      typeAD  codFrom  codTo
# cod
# 1     1.org        1      2
# 2     1.org        2      3
# 3     1.org        3      4
# 4     1.org        4      5
# 5     1.org        5      6
# 6     1.org        6      7
# 7     1.org        7      8
# 8     1.org        7      9
# 9     1.org        7     10
# 10    1.org        6     11
# 11    1.org       11     12
# 12    1.org       11     13
# 13    1.org       11     14
# 14    1.org        5     15
# 15    1.org       15     16
# 16    1.org       15     17
# 17    1.org        5     18
# 18    1.org       18     19
# 19    1.org       18     20
# 20    1.org        3     21
# 21    1.org       21     22
# 22    1.org       22     23
# 23    1.org       23     24
# 24    1.org       24     25
# 25    1.org       24     26
# 26    1.org       24     27
# 27    1.org       23     28
# 28    1.org       28     29
# 29    1.org       28     30
# 30    1.org       28     31
# ..      ...      ...    ...
# 87   1.prop       27     88
# 88   1.prop       27     89
# 89   1.prop       29     90
# 90   1.prop       29     91
# 91   1.prop       29     92
# 92   1.prop       29     93
# 93   1.prop       30     94
# 94   1.prop       30     95
# 95   1.prop       30     96
# 96   1.prop       30     97
# 97   1.prop       31     98
# 98   1.prop       31     99
# 99   1.prop       31    100
# 100  1.prop       31    101
# 101  1.prop       33    102
# 102  1.prop       33    103
# 103  1.prop       33    104
# 104  1.prop       33    105
# 105  1.prop       34    106
# 106  1.prop       34    107
# 107  1.prop       34    108
# 108  1.prop       34    109
# 109  1.prop       36    110
# 110  1.prop       36    111
# 111  1.prop       36    112
# 112  1.prop       36    113
# 113  1.prop       37    114
# 114  1.prop       37    115
# 115  1.prop       37    116
# 116  1.prop       37    117
#
# [116 rows x 3 columns]
# #----------=----------#
# tbSTP:
#        strNAME strTYPE                                 strVALUE  codNO
# cod
# 0          STP    root                                               1
# 1      Bachata     mod                                               2
# 2           V1     sub                                               3
# 3     Condutor    cond                                               4
# 4          BAS     tag                                               5
# 5          LAT     tag                                               6
# 6          ESQ     tag                                               7
# 7          CAL    leaf                                               8
# 8          CHA    leaf                                               9
# 9          BAS    leaf                                              10
# 10         DIR     tag                                              11
# 11         CAL    leaf                                              12
# 12         CHA    leaf                                              13
# 13         BAS    leaf                                              14
# 14         VER     tag                                              15
# 15         FRT    leaf                                              16
# 16         TRS    leaf                                              17
# 17         LUG     tag                                              18
# 18         ESQ    leaf                                              19
# 19         DIR    leaf                                              20
# 20   Conduzido    cond                                              21
# 21         BAS     tag                                              22
# 22         LAT     tag                                              23
# 23         ESQ     tag                                              24
# 24         CAL    leaf                                              25
# 25         CHA    leaf                                              26
# 26         BAS    leaf                                              27
# 27         DIR     tag                                              28
# 28         CAL    leaf                                              29
# 29         CHA    leaf                                              30
# ..         ...     ...                                      ...    ...
# 87       FIRST    prop                                   pE.ABR     88
# 88        LAST    prop                                  pD.JUN*     89
# 89        NAME    prop  STP_Bachata_V1_Condutor_BAS_LAT_DIR_CAL     90
# 90       TOTAL    prop                                       15     91
# 91       FIRST    prop                                   pD.ABR     92
# 92        LAST    prop                                  pE.JUN*     93
# 93        NAME    prop  STP_Bachata_V1_Condutor_BAS_LAT_DIR_CHA     94
# 94       TOTAL    prop                                       15     95
# 95       FIRST    prop                                   pD.ABR     96
# 96        LAST    prop                                   pD.LUG     97
# 97        NAME    prop  STP_Bachata_V1_Condutor_BAS_LAT_DIR_BAS     98
# 98       TOTAL    prop                                       10     99
# 99       FIRST    prop                                   pD.ABR    100
# 100       LAST    prop                                  pE.JUN*    101
# 101       NAME    prop      STP_Bachata_V1_Condutor_BAS_VER_FRT    102
# 102      TOTAL    prop                                       10    103
# 103      FIRST    prop                                   pE.FRT    104
# 104       LAST    prop                                  pD.JUN*    105
# 105       NAME    prop      STP_Bachata_V1_Condutor_BAS_VER_TRS    106
# 106      TOTAL    prop                                       10    107
# 107      FIRST    prop                                   pD.TRS    108
# 108       LAST    prop                                  pE.JUN*    109
# 109       NAME    prop      STP_Bachata_V1_Condutor_BAS_LUG_ESQ    110
# 110      TOTAL    prop                                       10    111
# 111      FIRST    prop                                   pE.LUG    112
# 112       LAST    prop                                  pD.LUG*    113
# 113       NAME    prop      STP_Bachata_V1_Condutor_BAS_LUG_DIR    114
# 114      TOTAL    prop                                       10    115
# 115      FIRST    prop                                   pD.LUG    116
# 116       LAST    prop                                  pE.LUG*    117
#
# [117 rows x 4 columns]
# #----------=----------#
# view DePara:
#      typeAD  codFrom from_strNAME from_strTYPE from_strVALUE  codTo  \
# cod
# 1     1.org        1          STP         root                    2
# 2     1.org        2      Bachata          mod                    3
# 3     1.org        3           V1          sub                    4
# 4     1.org        4     Condutor         cond                    5
# 5     1.org        5          BAS          tag                    6
# 6     1.org        6          LAT          tag                    7
# 7     1.org        7          ESQ          tag                    8
# 8     1.org        7          ESQ          tag                    9
# 9     1.org        7          ESQ          tag                   10
# 10    1.org        6          LAT          tag                   11
# 11    1.org       11          DIR          tag                   12
# 12    1.org       11          DIR          tag                   13
# 13    1.org       11          DIR          tag                   14
# 14    1.org        5          BAS          tag                   15
# 15    1.org       15          VER          tag                   16
# 16    1.org       15          VER          tag                   17
# 17    1.org        5          BAS          tag                   18
# 18    1.org       18          LUG          tag                   19
# 19    1.org       18          LUG          tag                   20
# 20    1.org        3           V1          sub                   21
# 21    1.org       21    Conduzido         cond                   22
# 22    1.org       22          BAS          tag                   23
# 23    1.org       23          LAT          tag                   24
# 24    1.org       24          ESQ          tag                   25
# 25    1.org       24          ESQ          tag                   26
# 26    1.org       24          ESQ          tag                   27
# 27    1.org       23          LAT          tag                   28
# 28    1.org       28          DIR          tag                   29
# 29    1.org       28          DIR          tag                   30
# 30    1.org       28          DIR          tag                   31
# ..      ...      ...          ...          ...           ...    ...
# 87   1.prop       27          BAS         leaf                   88
# 88   1.prop       27          BAS         leaf                   89
# 89   1.prop       29          CAL         leaf                   90
# 90   1.prop       29          CAL         leaf                   91
# 91   1.prop       29          CAL         leaf                   92
# 92   1.prop       29          CAL         leaf                   93
# 93   1.prop       30          CHA         leaf                   94
# 94   1.prop       30          CHA         leaf                   95
# 95   1.prop       30          CHA         leaf                   96
# 96   1.prop       30          CHA         leaf                   97
# 97   1.prop       31          BAS         leaf                   98
# 98   1.prop       31          BAS         leaf                   99
# 99   1.prop       31          BAS         leaf                  100
# 100  1.prop       31          BAS         leaf                  101
# 101  1.prop       33          FRT         leaf                  102
# 102  1.prop       33          FRT         leaf                  103
# 103  1.prop       33          FRT         leaf                  104
# 104  1.prop       33          FRT         leaf                  105
# 105  1.prop       34          TRS         leaf                  106
# 106  1.prop       34          TRS         leaf                  107
# 107  1.prop       34          TRS         leaf                  108
# 108  1.prop       34          TRS         leaf                  109
# 109  1.prop       36          ESQ         leaf                  110
# 110  1.prop       36          ESQ         leaf                  111
# 111  1.prop       36          ESQ         leaf                  112
# 112  1.prop       36          ESQ         leaf                  113
# 113  1.prop       37          DIR         leaf                  114
# 114  1.prop       37          DIR         leaf                  115
# 115  1.prop       37          DIR         leaf                  116
# 116  1.prop       37          DIR         leaf                  117
#
#     to_strNAME to_strTYPE                              to_strVALUE
# cod
# 1      Bachata        mod
# 2           V1        sub
# 3     Condutor       cond
# 4          BAS        tag
# 5          LAT        tag
# 6          ESQ        tag
# 7          CAL       leaf
# 8          CHA       leaf
# 9          BAS       leaf
# 10         DIR        tag
# 11         CAL       leaf
# 12         CHA       leaf
# 13         BAS       leaf
# 14         VER        tag
# 15         FRT       leaf
# 16         TRS       leaf
# 17         LUG        tag
# 18         ESQ       leaf
# 19         DIR       leaf
# 20   Conduzido       cond
# 21         BAS        tag
# 22         LAT        tag
# 23         ESQ        tag
# 24         CAL       leaf
# 25         CHA       leaf
# 26         BAS       leaf
# 27         DIR        tag
# 28         CAL       leaf
# 29         CHA       leaf
# 30         BAS       leaf
# ..         ...        ...                                      ...
# 87       FIRST       prop                                   pE.ABR
# 88        LAST       prop                                  pD.JUN*
# 89        NAME       prop  STP_Bachata_V1_Condutor_BAS_LAT_DIR_CAL
# 90       TOTAL       prop                                       15
# 91       FIRST       prop                                   pD.ABR
# 92        LAST       prop                                  pE.JUN*
# 93        NAME       prop  STP_Bachata_V1_Condutor_BAS_LAT_DIR_CHA
# 94       TOTAL       prop                                       15
# 95       FIRST       prop                                   pD.ABR
# 96        LAST       prop                                   pD.LUG
# 97        NAME       prop  STP_Bachata_V1_Condutor_BAS_LAT_DIR_BAS
# 98       TOTAL       prop                                       10
# 99       FIRST       prop                                   pD.ABR
# 100       LAST       prop                                  pE.JUN*
# 101       NAME       prop      STP_Bachata_V1_Condutor_BAS_VER_FRT
# 102      TOTAL       prop                                       10
# 103      FIRST       prop                                   pE.FRT
# 104       LAST       prop                                  pD.JUN*
# 105       NAME       prop      STP_Bachata_V1_Condutor_BAS_VER_TRS
# 106      TOTAL       prop                                       10
# 107      FIRST       prop                                   pD.TRS
# 108       LAST       prop                                  pE.JUN*
# 109       NAME       prop      STP_Bachata_V1_Condutor_BAS_LUG_ESQ
# 110      TOTAL       prop                                       10
# 111      FIRST       prop                                   pE.LUG
# 112       LAST       prop                                  pD.LUG*
# 113       NAME       prop      STP_Bachata_V1_Condutor_BAS_LUG_DIR
# 114      TOTAL       prop                                       10
# 115      FIRST       prop                                   pD.LUG
# 116       LAST       prop                                  pE.LUG*
#
# [116 rows x 9 columns]
# #####-#####-#####-#####-#####
# #####-#####-#####-#####-#####
