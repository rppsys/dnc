# %%
# Esse deu certo e vou deixar assim de referencia
# %matplotlib notebook

from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from matplotlib.artist import Artist
import numpy as np

def getImage(path, zoom=0.4):
    return OffsetImage(plt.imread(path), zoom=zoom)

x = []
y = []
pD_image_path = '/home/ronie/prog/dnc/lab/pD.PNG'
pE_image_path = '/home/ronie/prog/dnc/lab/pE.PNG'

pD_x0 = 1
pD_y0 = 0


pE_x0 = -1
pE_y0 = 0

figure, ax = plt.subplots()

# Setting limits for x and y axis
ax.set_xlim(-10, 10)
ax.set_ylim(-10, 10)
ax.grid()

# Inicializa pD e pE
pD_xx = pD_x0
pD_yy = 0

pE_xx = pE_x0
pE_yy = 0



# Insere Pé Direito - Vai se Mover
abPD = AnnotationBbox(getImage(pD_image_path), (pD_xx, pD_yy), frameon=False)
ax.add_artist(abPD) 

# Insere Pé Esquerdo - Vai ficar parado
abPE = AnnotationBbox(getImage(pE_image_path), (pE_xx, pE_yy), frameon=False)
ax.add_artist(abPE) 

# Since plotting a single graph
# line,  = ax.plot(0, 0,'bo') 

meu_hline = ax.axhline(y=pD_yy, color="black", linestyle=":")
meu_vline = ax.axvline(x=pD_xx, color="black", linestyle=":")




def animation_function(i):
    x = i
    y = pD_y0
    
    pD_xx = i  
    pD_yy = pD_y0
    #pD_yy = i
    
    #line.set_xdata(x)
    #line.set_ydata(y)
    abPD.xybox = (pD_xx,pD_yy)
    
    meu_vline.set_xdata(pD_xx)
    meu_hline.set_ydata(pD_yy)
    
       
    
    
    #return line,abPD,meu_vline,
    return abPD,meu_vline,
  
animation = FuncAnimation(figure,
                          func = animation_function,
                          frames = np.arange(pD_x0 + 1, 6, 0.5), 
                          interval = 100)

animation.save('abre4.mp4', fps=10)


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Posição Final

from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from matplotlib.artist import Artist
import numpy as np

def getImage(path, zoom=0.4):
    return OffsetImage(plt.imread(path), zoom=zoom)

x = []
y = []
pD_image_path = '/home/ronie/prog/dnc/lab/pD.PNG'
pE_image_path = '/home/ronie/prog/dnc/lab/pE.PNG'

pD_x0 = 1
pE_x0 = -1

figure, ax = plt.subplots()

# Setting limits for x and y axis
ax.set_xlim(-10, 10)
ax.set_ylim(-10, 10)

# Inicializa pD e pE
pD_xx = pD_x0
pD_yy = 1

pE_xx = pE_x0
pE_yy = 1



# Insere Pé Direito - Vai se Mover
abPD = AnnotationBbox(getImage(pD_image_path), (5.5+1, pD_yy), frameon=False)
ax.add_artist(abPD) 

# Insere Pé Esquerdo - Vai ficar parado
abPE = AnnotationBbox(getImage(pE_image_path), (pE_xx, pE_yy), frameon=False)
ax.add_artist(abPE) 

# Since plotting a single graph
line,  = ax.plot(0, -5,'bo') 

plt.show()

# %%
frames = np.arange(pD_x0 + 1, 6, 0.5)

# %%
frames
# Out:
# array([2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5])
