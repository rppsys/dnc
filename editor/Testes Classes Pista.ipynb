# %%
# %matplotlib notebook
import stepPlot as sp
Pista = sp.ClassePista('Pista',20)

Condutor = sp.ClasseAgente('Condutor',True,10,10,8,0)
Conduzido = sp.ClasseAgente('Conduzido',False,10,15,5,0)

Pista.putAgente(Condutor)
Pista.putAgente(Conduzido)

Pista.showAgentes()
# Out:
# <img src="data:image/png;base64,..." width="895.8333333333334">
# ClasseAgente(name=Condutor, b=True, x=10, y=10, h=8, t=0)
# ClasseAgente(name=Conduzido, b=False, x=10, y=15, h=5, t=0)

# %%
Pista.plotaAgentes()
# Out:
# <img src="data:image/png;base64,..." width="895.8333333333334">

# %%
Condutor.agenteDoStep('pD','ABR','')
# Out:
# Condutor - pD.ABR

# %%
Pista.plotaAgentes()
# Out:
# <img src="data:image/png;base64,..." width="895.8333333333334">

# %%
Conduzido.agenteDoStep('pE','ABR','')
# Out:
# Conduzido - pE.ABR

# %%
Pista.plotaAgentes()
# Out:
# <img src="data:image/png;base64,..." width="895.8333333333334">
